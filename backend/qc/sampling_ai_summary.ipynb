# %%
import gspread
import pandas as pd
import matplotlib.pyplot as plt
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("AI Summary Tagging").worksheet("Sampling")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../../raw_data/sampling_summary.csv', index=False)

# %%
df_clean
# Out:
#    tanggal_pengerjaan nama_sampling nama_qc asi_afi  id_tiket    case_status  \
# 15           3/6/2026          Azer  Neneng     ASI  23124849          Close
# 24           3/6/2026          Azer    Reza     ASI  23120982  Chat Category
# 25           3/6/2026          Azer     Aul     AFI  22901005  Chat Category
# 46           3/6/2026           Aul    Azer    ASI   23072810  Chat Category
# 54           3/6/2026           Aul  Neneng    ASI   22890090  Chat Category
# 55           3/6/2026           Aul    Reza    ASI   23075793  Chat Category
#
#              waktu_chat sentimen_pengguna revisi_sentimen masalah_pelanggan  \
# 15  2026-03-02 22:23:09            Netral         Negatif             Benar
# 24  2026-02-28 15:52:09            Netral         Negatif             Benar
# 25   2026-01-25 7:16:06            Netral         Negatif             Benar
# 46  2026-02-21 11:15:54            Netral                             Benar
# 54  2026-01-23 16:32:49            Netral                             Benar
# 55  2026-02-21 21:21:45            Netral                             Benar
#
#    solusi hasil_summary                                  alasan_tidak_suka  \
# 15  Benar           Bad         Negatif karena kendala pengajuan Pinjaman
# 24  Benar           Bad  Seharusnya sentimen Negatif karena pengguna ad...
# 25  Benar           Bad  Seharusnya sentimen Negatif karena pengguna me...
# 46  Benar         Benar
# 54  Benar         Benar
# 55  Benar         Benar
#
#    revisi_sentimen_ubah                                        reason_ubah  \
# 15               Netral  seharusnya netral karena user hanya bertanya k...
# 24               Netral  seharusnya sentimen netral karena user hanya b...
# 25               Netral  seharusnya sentimen netral karena user hanya b...
# 46              Negatif  Seharusnya sentimen Negatif karena pengguna me...
# 54              Negatif  Seharusnya sentimen Negatif karena pengguna me...
# 55              Negatif  Seharusnya sentimen Negatif karena pengguna me...
#
#    present file_screenshot file_screenshot_2 tanggal_meeting
# 15    TRUE    azer_1_1.png      azer_1_2.png        3/6/2026
# 24    TRUE    azer_2_1.png      azer_2_2.png        3/6/2026
# 25    TRUE                                          3/6/2026
# 46    TRUE                                          3/6/2026
# 54    TRUE                                          3/6/2026
# 55    TRUE                                          3/6/2026

# %%
df_clean = df.copy()

df_clean = df_clean[df_clean['present'] == "TRUE"]

df_clean.columns = (
    df_clean.columns
    .str.lower()
    .str.strip()
    .str.replace(' ', '_')
    .str.replace('/', '_')
)

df_clean.to_csv('../../dataset_qc/sampling_summary.csv')

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 1 to 55
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tanggal_pengerjaan    12 non-null     object
#  1   nama_sampling         12 non-null     object
#  2   nama_qc               12 non-null     object
#  3   asi_afi               12 non-null     object
#  4   id_tiket              12 non-null     object
#  5   case_status           12 non-null     object
#  6   waktu_chat            12 non-null     object
#  7   sentimen_pengguna     12 non-null     object
#  8   revisi_sentimen       12 non-null     object
#  9   masalah_pelanggan     12 non-null     object
#  10  solusi                12 non-null     object
#  11  hasil_summary         12 non-null     object
#  12  alasan_tidak_suka     12 non-null     object
#  13  revisi_sentimen_ubah  12 non-null     object
#  14  reason_ubah           12 non-null     object
#  15  present               12 non-null     object
#  16  file_screenshot       12 non-null     object
#  17  file_screenshot_2     12 non-null     object
#  18  tanggal_meeting       12 non-null     object
# dtypes: object(19)
# memory usage: 1.9+ KB
