# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/Credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']
creds = Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open('[4] AI QC Inbound CRM Review 语音智能质检打标复审').worksheet('Sampling')
data = sheet.get_all_records()

df = pd.DataFrame(data[0:], columns=data[0])
df.to_csv('../../raw_data/sampling_hotline.csv', index=False)

# %%
# Removing a column and apply lowercase & removing extra spaces in data
df_clean = (
    df[df['present'] == 'TRUE'].copy()
)

# Lowering column names and removing extra spaces
df_clean.columns = (
    df_clean
    .columns.str.lower()
    .str.strip()
    .str.replace(' ','_')
)

df_clean.to_csv('../../dataset_qc/sampling_hotline.csv', index=False)

df_clean
# Out:
#    tanggal_sampling agent_sampling tanggal_pengerjaan checker asi/afi  \
# 5        04/01/2026           Reza         03/30/2026     Aul    ASI
# 9        04/01/2026           Azer         03/27/2026  Neneng    ASI
# 14       04/02/2026          Aulia         03/27/2026  Neneng    ASI
# 18       04/09/2026          Aulia         03/31/2026    Reza    ASI
# 23       04/09/2026          Aulia         03/30/2026  Neneng    ASI
# 24       04/09/2026         Neneng         04/01/2026     Aul    ASI
# 26       04/09/2026         Neneng         03/30/2026    Azer    ASI
# 28       04/10/2026           Azer         04/02/2026    Reza     AFI
# 32       04/10/2026           Azer         03/31/2026     Aul    ASI
# 34       04/15/2026          Aulia         04/07/2026    Reza    ASI
# 36       04/15/2026          Aulia         04/10/2026  Neneng    ASI
# 42       04/15/2026         Neneng         04/06/2026    Azer    ASI
# 44       04/15/2026         Neneng         04/10/2026     Aul    ASI
# 47       04/21/2026         Neneng         04/16/2026     Aul    ASI
# 48       04/21/2026         Neneng         04/15/2026    Azer    ASI
# 50       04/21/2026          Aulia         04/14/2026    Azer    ASI
# 52       04/21/2026          Aulia         04/16/2026  Neneng    ASI
# 54       04/23/2026           Reza         04/13/2026    Azer    ASI
# 56       04/23/2026           Reza         04/15/2026     Aul     AFI
# 59       04/23/2026           Reza         04/17/2026  Neneng    ASI
# 60       04/23/2026           Azer         04/13/2026     Aul    ASI
# 62       04/23/2026           Azer         04/13/2026  Neneng    ASI
#
#           waktu_inbound nomor_inbound                        nama_agent  \
# 5   2026-03-25 19:09:05   0212***5900                    CVGLC_Limawati
# 9   2026-03-26 14:44:43  0831****2552                           Isnaini
# 14  2026-03-13 15:00:17  0878****4293            TCHL_Fatul Nur Habibah
# 18  2026-03-13 13:07:53  0882****3728                    CVGLC_Limawati
# 23  2026-03-25 13:39:51  0895****9798           Meyke Indah Puspitasari
# 24  2026-03-16 22:02:28  0857****1075               TCHL_Davit Suryawan
# 26   2026-03-16 9:22:21  0858****5814       TCHL_Afifuddin Reza Arifani
# 14  Percakapan Normal & Aturan lainnya     On Target/Not HC
# 18                                      Miss Target/ Not HC
# 23                                      Miss Target/ Not HC
# 24                                           Miss Target/HC
# 26  Percakapan Normal & Aturan lainnya  Miss Target/ Not HC
# 28                                             On Target/HC
# 32                                      Miss Target/ Not HC
# 34
# 36
# 42                                      Miss Target/ Not HC
# 44
# 47
# 48
# 50
# 52
# 54
# 56
# 59
# 60
# 62
#
#                       kejelasan_suara_ubah   suara_lain_ubah  \
# 5                              Cukup Jelas  0 Satu pembicara
# 9                              Cukup Jelas  0 Satu pembicara
# 14  Sangat jelas, tidak bising sama sekali  0 Satu pembicara
# 18
# 23
# 24
# 26
# 28
# 32
# 34
# 36
# 42
# 44
# 47
# 48
# 50
# 52
# 54
# 56
# 59
# 60
# 62
#
#    kelengkapan_rekaman_ubah  \
# 5              1 Tidak Utuh
# 9              1 Tidak Utuh
# 14             1 Tidak Utuh
# 18
# 23
# 24
# 26
# 28
# 32
# 34
# 36
# 42
# 44
# 47
# 48
# 50
# 52
# 54
# 56
# 59
# 60
# 62
#
#                                                alasan present  \
# 5                 Seharusnya tetep HC karena user ada    TRUE
# 9                                                        TRUE
# 14  seharusnya HC karena user ingin melaporkan aku...    TRUE
# 18                                                       TRUE
# 23                                                       TRUE
# 24                                                       TRUE
# 26                                                       TRUE
# 28  seharusnya on target HC namun eja mengisi on t...    TRUE
# 32  seharusnya miss target not HC namun aul mengis...    TRUE
# 34                                                       TRUE
# 36                                                       TRUE
# 42                                                       TRUE
# 44                                                       TRUE
# 47                                                       TRUE
# 48                                                       TRUE
# 50                                                       TRUE
# 52                                                       TRUE
# 54                                                       TRUE
# 56                                                       TRUE
# 59                                                       TRUE
# 60                                                       TRUE
# 62                                                       TRUE
#
#               file_screenshot tanggal_meeting
# 5     reza_case_hotline_1.png      04/02/2026
# 9     azer_case_hotline_1.png      04/02/2026
# 14     aul_case_hotline_1.png      04/02/2026
# 18     aul_case_hotline_2.png      04/10/2026
# 23     aul_case_hotline_3.png      04/10/2026
# 24  neneng_case_hotline_2.png      04/10/2026
# 26  neneng_case_hotline_3.png      04/10/2026
# 28    azer_case_hotline_2.png      04/10/2026
# 32    azer_case_hotline_3.png      04/10/2026
# 34     aul_case_hotline_4.png      04/17/2026
# 36     aul_case_hotline_5.png      04/17/2026
# 42  neneng_case_hotline_4.png      04/17/2026
# 44  neneng_case_hotline_5.png      04/17/2026
# 47  neneng_case_hotline_6.png      04/24/2026
# 48  neneng_case_hotline_7.png      04/24/2026
# 50     aul_case_hotline_6.png      04/24/2026
# 52     aul_case_hotline_7.png      04/24/2026
# 54    reza_case_hotline_5.png      04/24/2026
# 56    reza_case_hotline_6.png      04/24/2026
# 59    reza_case_hotline_7.png      04/24/2026
# 60    azer_case_hotline_6.png      04/24/2026
# 62    azer_case_hotline_7.png      04/24/2026
#
# [22 rows x 33 columns]
