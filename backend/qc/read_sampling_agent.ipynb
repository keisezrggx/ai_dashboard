# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/Credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']
creds = Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open('Human Agent QC').worksheet('Sampling')
data = sheet.get_all_records()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../../raw_data/human_agent_qc.csv', index=False)

# %%
# clean data
df_clean = df.copy()

df_clean = (
    df_clean
    .loc[df_clean['present'] == "TRUE"]
    .replace('', '-', regex=True)
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 23 to 400
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tanggal_pengerjaan  72 non-null     object
#  1   nama_sampling       72 non-null     object
#  2   nama_qc             72 non-null     object
#  3   asi/afi             72 non-null     object
#  4   chat_id             72 non-null     object
#  5   code_robot          72 non-null     object
#  6   result_qc           72 non-null     object
#  7   code                72 non-null     object
#  8   description         72 non-null     object
#  9   reason              72 non-null     object
#  10  result_qc_ubah      72 non-null     object
#  11  reason_ubah         72 non-null     object
#  12  present             72 non-null     object
#  13  file_screenshot     72 non-null     object
#  14  file_screenshot_2   72 non-null     object
#  15  file_screenshot_3   72 non-null     object
#  16  tanggal_meeting     72 non-null     object
# dtypes: object(17)
# memory usage: 10.1+ KB

# %%
df_clean
# Out:
#     tanggal_pengerjaan nama_sampling nama_qc asi/afi  \
# 23           1/22/2026           Aul    Reza     AFI
# 26           1/22/2026           Aul    Azer    ASI
# 27           1/22/2026           Aul  Neneng    ASI
# 29           1/22/2026          Reza    Azer    ASI
# 31           1/22/2026          Reza  Neneng    ASI
# ..                 ...           ...     ...     ...
# 371          4/10/2026        Neneng     Aul    ASI
# 377          4/15/2026           Aul    Azer    ASI
# 387          4/15/2026           Aul    Reza    ASI
# 394          4/15/2026        Neneng    Reza    ASI
# 400          4/15/2026        Neneng     Aul    ASI
#
#                          chat_id code_robot            result_qc code  \
# 23     2-65797664-3-1_1768265506  RC01-01\r  Normal Conversation    -
# 26   2-2048889089-3-1_1768253068     E01-01  Normal Conversation    -
# 27     2-24284311-3-1_1768231219    RC02-01  Normal Conversation    -
# 29      2-6761515-3-1_1768266392    LC12-01              Correct    -
# 31   2-2055201768-3-1_1768235480    RC02-01  Normal Conversation    -
# ..                           ...        ...                  ...  ...
# 371   2-103823393-3-1_1774868119     LC3-01              Correct    -
# 377  2-2033188536-3-1_1775566669     C06-01  Normal Conversation    -
# 387  2-2031751986-3-1_1775463763  LC12-02\r  Normal Conversation    -
# 394   2-118158330-3-1_1775603513  RC02-01\r              Correct    -
# 400     2-3776282-3-1_1775650596     LC3-01              Correct    -
#
#     description reason       result_qc_ubah  \
# 23            -      -                    -
# 26            -      -                    -
# 27            -      -                    -
# 29            -      -                    -
# 31            -      -                    -
# ..          ...    ...                  ...
# 371           -      -  Normal Conversation
# 377           -      -                    -
# 387           -      -              Correct
# 394           -      -  Normal Conversation
# 400           -      -  Normal Conversation
#
#                                            reason_ubah present  \
# 23                                                   -    TRUE
# 26                                                   -    TRUE
# 27                                                   -    TRUE
# 29                                                   -    TRUE
# 31                                                   -    TRUE
# ..                                                 ...     ...
# 371  pertanyaan agent berbeda antara apakah sudah m...    TRUE
# 377                                                  -    TRUE
# 387                  Robot sudah benar dan Agent salah    TRUE
# 394     Agent sudah menawarkan bantuan sebelum closing    TRUE
# 400                                 Agent sudah sesuai    TRUE
#
#           file_screenshot     file_screenshot_2     file_screenshot_3  \
# 23       aul_case_1_1.png      aul_case_1_2.png                     -
# 26       aul_case_2_1.png      aul_case_2_2.png                     -
# 27       aul_case_3_1.png      aul_case_3_2.png                     -
# 29      reza_case_1_1.png     reza_case_1_2.png                     -
# 31      reza_case_2_1.png     reza_case_2_2.png                     -
# ..                    ...                   ...                   ...
# 371  neneng_case_14_1.png  neneng_case_14_2.png                     -
# 377     aul_case_15_1.png     aul_case_15_2.png                     -
# 387     aul_case_16_1.png     aul_case_16_2.png     aul_case_16_3.png
# 394  neneng_case_15_1.png  neneng_case_15_2.png  neneng_case_15_3.png
# 400  neneng_case_16_1.png  neneng_case_16_2.png  neneng_case_16_3.png
#
#     tanggal_meeting
# 23        1/23/2026
# 26        1/23/2026
# 27        1/23/2026
# 29        1/23/2026
# 31        1/23/2026
# ..              ...
# 371       4/10/2026
# 377       4/16/2026
# 387       4/16/2026
# 394       4/16/2026
# 400       4/16/2026
#
# [72 rows x 17 columns]

# %%
df_clean.to_csv('../../dataset_qc/sampling_agent.csv')
