# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/Credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']
creds = Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open('Human Agent QC').worksheet('Sampling')
data = sheet.get_all_records()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../../raw_data/human_agent_qc.csv', index=False)

# %%
# clean data
df_clean = df.copy()

df_clean = (
    df_clean
    .loc[df_clean['present'] == "TRUE"]
    .replace('', '-', regex=True)
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68 entries, 23 to 371
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tanggal_pengerjaan  68 non-null     object
#  1   nama_sampling       68 non-null     object
#  2   nama_qc             68 non-null     object
#  3   asi/afi             68 non-null     object
#  4   chat_id             68 non-null     object
#  5   code_robot          68 non-null     object
#  6   result_qc           68 non-null     object
#  7   code                68 non-null     object
#  8   description         68 non-null     object
#  9   reason              68 non-null     object
#  10  result_qc_ubah      68 non-null     object
#  11  reason_ubah         68 non-null     object
#  12  present             68 non-null     object
#  13  file_screenshot     68 non-null     object
#  14  file_screenshot_2   68 non-null     object
#  15  tanggal_meeting     68 non-null     object
# dtypes: object(16)
# memory usage: 9.0+ KB

# %%
df_clean
# Out:
#     tanggal_pengerjaan nama_sampling nama_qc asi/afi  \
# 23           1/22/2026           Aul    Reza     AFI
# 26           1/22/2026           Aul    Azer    ASI
# 27           1/22/2026           Aul  Neneng    ASI
# 29           1/22/2026          Reza    Azer    ASI
# 31           1/22/2026          Reza  Neneng    ASI
# ..                 ...           ...     ...     ...
# 344           4/8/2026           Aul    Azer    ASI
# 350           4/9/2026          Azer     Aul    ASI
# 353           4/9/2026          Azer  Neneng    ASI
# 366          4/10/2026        Neneng    Azer    ASI
# 371          4/10/2026        Neneng     Aul    ASI
#
#                          chat_id code_robot            result_qc code  \
# 23     2-65797664-3-1_1768265506  RC01-01\r  Normal Conversation    -
# 26   2-2048889089-3-1_1768253068     E01-01  Normal Conversation    -
# 27     2-24284311-3-1_1768231219    RC02-01  Normal Conversation    -
# 29      2-6761515-3-1_1768266392    LC12-01              Correct    -
# 31   2-2055201768-3-1_1768235480    RC02-01  Normal Conversation    -
# ..                           ...        ...                  ...  ...
# 344    2-15712514-3-1_1774962104     LC1-03              Correct    -
# 350    2-14001659-3-1_1774863735    LC12-01              Correct    -
# 353  2-2016622067-3-1_1774792818    RC01-01  Normal Conversation    -
# 366  2-2040458125-3-1_1774783986    RC01-01              Correct    -
# 371   2-103823393-3-1_1774868119     LC3-01              Correct    -
#
#     description reason       result_qc_ubah  \
# 23            -      -                    -
# 26            -      -                    -
# 27            -      -                    -
# 29            -      -                    -
# 31            -      -                    -
# ..          ...    ...                  ...
# 344           -      -                    -
# 350           -      -                    -
# 353           -      -                    -
# 366           -      -  Normal Conversation
# 371           -      -  Normal Conversation
#
#                                            reason_ubah present  \
# 23                                                   -    TRUE
# 26                                                   -    TRUE
# 27                                                   -    TRUE
# 29                                                   -    TRUE
# 31                                                   -    TRUE
# ..                                                 ...     ...
# 344                                                  -    TRUE
# 350                                                  -    TRUE
# 353                                                  -    TRUE
# 366          Agent sudah ada tanya kejelasan sebelumny    TRUE
# 371  pertanyaan agent berbeda antara apakah sudah m...    TRUE
#
#           file_screenshot     file_screenshot_2 tanggal_meeting
# 23       aul_case_1_1.png      aul_case_1_2.png       1/23/2026
# 26       aul_case_2_1.png      aul_case_2_2.png       1/23/2026
# 27       aul_case_3_1.png      aul_case_3_2.png       1/23/2026
# 29      reza_case_1_1.png     reza_case_1_2.png       1/23/2026
# 31      reza_case_2_1.png     reza_case_2_2.png       1/23/2026
# ..                    ...                   ...             ...
# 344     aul_case_14_1.png     aul_case_14_2.png       4/10/2026
# 350    azer_case_13_1.png    azer_case_13_2.png       4/10/2026
# 353    azer_case_14_1.png    azer_case_14_2.png       4/10/2026
# 366  neneng_case_13_1.png  neneng_case_13_2.png       4/10/2026
# 371  neneng_case_14_1.png  neneng_case_14_2.png       4/10/2026
#
# [68 rows x 16 columns]

# %%
df_clean.to_csv('../../dataset_qc/sampling_agent.csv')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
