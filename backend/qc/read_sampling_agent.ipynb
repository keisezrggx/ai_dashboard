# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/Credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']
creds = Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open('Human Agent QC').worksheet('Sampling')
data = sheet.get_all_records()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
# clean data
df_clean = df.copy()

df_clean = (
    df_clean
    .drop(df_clean.columns[[3,4]], axis=1)
    .loc[df_clean['present'] == "TRUE"]
    .replace('', '-', regex=True)
    .reset_index(drop=True)
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tanggal_pengerjaan  10 non-null     object
#  1   nama_sampling       10 non-null     object
#  2   nama_qc             10 non-null     object
#  3   code_robot          10 non-null     object
#  4   result_qc           10 non-null     object
#  5   code                10 non-null     object
#  6   description         10 non-null     object
#  7   reason              10 non-null     object
#  8   result_qc_ubah      10 non-null     object
#  9   reason_ubah         10 non-null     object
#  10  present             10 non-null     object
#  11  file_screenshot     10 non-null     object
#  12  file_screenshot_2   10 non-null     object
#  13  tanggal_meeting     10 non-null     object
# dtypes: object(14)
# memory usage: 1.2+ KB

# %%
df_clean
# Out:
#   tanggal_pengerjaan nama_sampling nama_qc code_robot            result_qc  \
# 0          1/22/2026           Aul    Reza  RC01-01\r  Normal Conversation
# 1          1/22/2026           Aul    Azer     E01-01  Normal Conversation
# 2          1/22/2026           Aul  Neneng    RC02-01  Normal Conversation
# 3          1/22/2026          Reza    Azer    LC12-01              Correct
# 4          1/22/2026          Reza  Neneng    RC02-01  Normal Conversation
# 5          1/22/2026          Reza     Aul    RC01-01  Normal Conversation
# 6          1/22/2026          Azer  Neneng     E01-01              Correct
# 7          1/22/2026          Azer  Neneng     LC7-01  Rule Judgment Error
# 8          1/22/2026          Azer  Neneng    RC01-01              Correct
# 9          1/28/2026        Neneng     Aul    LC10-01  Normal Conversation
#
#       code                                        description  \
# 0        -                                                  -
# 1        -                                                  -
# 2        -                                                  -
# 3        -                                                  -
# 4        -                                                  -
# 5        -                                                  -
# 6   E01-01  Agen tidak menyampaikan permohonan maaf atau m...
# 7        -                                                  -
# 8  RC01-01  Agen tidak menanyakan dengan jelas apakah masa...
# 9  LC10-01                                              tes 1
#
#                                               reason       result_qc_ubah  \
# 0                                                  -                    -
# 1                                                  -                    -
# 2                                                  -                    -
# 3                                                  -                    -
# 4                                                  -                    -
# 5                                                  -                    -
# 6  Agent sudah melakukan Empathy pada menit 08:02:22  Normal Conversation
# 7                                                  -                    -
# 8  seharusnya normal karena ketika agent konfirma...  Normal Conversation
# 9                                              tes 2              Correct
#
#   reason_ubah present    file_screenshot  file_screenshot_2 tanggal_meeting
# 0           -    TRUE   aul_case_1_1.png   aul_case_1_2.png       1/23/2026
# 1           -    TRUE   aul_case_2_1.png   aul_case_2_2.png       1/23/2026
# 2           -    TRUE   aul_case_3_1.png   aul_case_3_2.png       1/23/2026
# 3           -    TRUE  reza_case_1_1.png  reza_case_1_2.png       1/23/2026
# 4           -    TRUE  reza_case_2_1.png  reza_case_2_2.png       1/23/2026
# 5           -    TRUE  reza_case_3_1.png  reza_case_3_2.png       1/23/2026
# 6           -    TRUE  azer_case_1_1.png  azer_case_1_2.png       1/23/2026
# 7           -    TRUE  azer_case_2_1.png  azer_case_2_2.png       1/23/2026
# 8           -    TRUE  azer_case_3_1.png  azer_case_3_2.png       1/23/2026
# 9       tes 3    TRUE                  -                  -       1/29/2026

# %%
df_clean.to_csv('../../dataset_qc/sampling_agent.csv')
