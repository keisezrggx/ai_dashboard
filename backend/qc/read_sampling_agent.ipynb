# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/Credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']
creds = Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open('LIVE CHAT AI QC AGENT').worksheet('Sampling')
data = sheet.get_all_records()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
# clean data
df_clean = df.copy()

df_clean = (
    df_clean
    .drop(df_clean.columns[[3,4]], axis=1)
    .loc[df_clean['present'] == "TRUE"]
    .fillna(' ')
    .reset_index(drop=True)
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tanggal_pengerjaan  4 non-null      object
#  1   nama_sampling       4 non-null      object
#  2   nama_qc             4 non-null      object
#  3   code_robot          4 non-null      object
#  4   result_qc           4 non-null      object
#  5   code                4 non-null      object
#  6   description         4 non-null      object
#  7   reason              4 non-null      object
#  8   result_qc_awal      4 non-null      object
#  9   reason_awal         4 non-null      object
#  10  present             4 non-null      object
#  11  file_screenshot     4 non-null      object
#  12  file_screenshot_2   4 non-null      object
#  13  tanggal_meeting     4 non-null      object
# dtypes: object(14)
# memory usage: 580.0+ bytes

# %%
df_clean
# Out:
#   tanggal_pengerjaan nama_sampling nama_qc code_robot            result_qc  \
# 0         12/12/2025          Reza  Neneng     LC7-01  Normal Conversation
# 1         12/12/2025           Aul    Azer   LC7-01\r  Rule Judgment Error
# 2         12/12/2025          Azer     Aul   E01-01\r  Rule Judgment Error
# 3         12/12/2025        Neneng    Reza    LC12-02              Correct
#
#        code                                        description  \
# 0    LC7-01                               Kesalahan ejaan kata
# 1  LC7-01\r           Standar Percakapan: Kesalahan ejaan kata
# 2  E01-01\r  Standar Ucapan: Agen tidak menyampaikan permoh...
# 3                        Tanggapan tertunda lebih dari 3 menit
#
#                                               reason       result_qc_awal  \
# 0                     Tidak ada kesalahan ejaan kata  Rule Judgment Error
# 1                    Tidak ada kesalahan ejaan kata   Rule Judgment Error
# 2  Agent sudah melakukan Empathy pada menit 00:43:28  Rule Judgment Error
# 3  Baik kak, mohon maaf atas ketidaknyamannya. Ak...  Normal Conversation
#
#                                    reason_awal present     file_screenshot  \
# 0               Tidak ada kesalahan ejaan kata    TRUE    reza_case1_1.png
# 1  Alasan: kata 'dikarenakan' ini sudah sesuai    TRUE     aul_case1_1.png
# 2                                                 TRUE    azer_case1_1.png
# 3                                                 TRUE  neneng_case1_1.png
#
#   file_screenshot_2 tanggal_meeting
# 0  reza_case1_2.png        1/2/2026
# 1   aul_case1_2.png        1/2/2026
# 2  azer_case1_2.png        1/2/2026
# 3  azer_case1_2.png        1/2/2026

# %%
df_clean.to_csv('../../dataset_qc/sampling_agent.csv')
