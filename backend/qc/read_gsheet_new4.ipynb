# %%
import streamlit as st
import pandas as pd
import numpy as np
import gspread
import plotly.express as px
import plotly.graph_objects as go

from datetime import timedelta
from google.oauth2.service_account import Credentials
from collections import defaultdict

# %%
# Read data from gsheet

SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']
creds = Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("[3] AI QC Inbound CRM Review 语音智能质检打标复审 ").worksheet("NEW 4")
data = sheet.get_all_values()

raw_headers = data[3]
rows = data[:4]
header_counter = defaultdict(int)
unique_header = []

for header in raw_headers:
    base = header if header.strip() != '' else 'Unnamed'
    header_counter[base] += 1

    if header_counter[base] == 1:
        unique_header.append(base)
    else:
        unique_header.append(f"{base}_{header_counter}[base]-1")

df = pd.DataFrame(data[2:], columns=unique_header)
df.to_csv('../../raw_data/raw_data_new4.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205346 entries, 0 to 205345
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   No                                205346 non-null  object
#  1   Tanggal Pengerjaan                205346 non-null  object
#  2   Checker                           205346 non-null  object
#  3   ASI/AFI                           205346 non-null  object
#  4   Waktu Inbound                     205346 non-null  object
#  5   Nomor Inbound                     205346 non-null  object
#  6   Nama Agent                        205346 non-null  object
#  7   Call ID                           205346 non-null  object
#  8   Durasi Bicara                     205346 non-null  object
#  9   Detik                             205346 non-null  object
#  10  Total Tiket Riskan                205346 non-null  object
#  11  Apakah Riskan?                    205346 non-null  object
#  12  Tinjauan CS                       205346 non-null  object
#  13  Status                            205346 non-null  object
#  14  Sampling user side                205346 non-null  object
#  15  Hasil Pemeriksaan Kualitas (old)  205346 non-null  object
#  16  Hasil ASR                         205346 non-null  object
#  17  Hasil Pemeriksaan Kualitas        205346 non-null  object
#  18  Efektif                           205346 non-null  object
#  19  Kejelasan Suara                   205346 non-null  object
#  20  Suara Lain                        205346 non-null  object
#  21  Kelengkapan Rekaman               205346 non-null  object
#  22  Agent Sampling                    205346 non-null  object
# dtypes: object(23)
# memory usage: 36.0+ MB

# %%
# Data Cleaning
df_clean = df.copy()

# Hapus 2 baris awal
df_clean = df_clean.iloc[2:].reset_index(drop=True)

# Bersihkan nama kolom dan ganti yang kosong
df_clean.columns = [col.strip() if col.strip() else 'Catatan Tambahan' for col in df_clean.columns]

# Konversi kolom datetime jika ada
for col in ['Tanggal Pengerjaan', 'Waktu Inbound']:
    if col in df_clean.columns:
        df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')

# Konversi kolom numerik
if 'No' in df_clean.columns:
    df_clean['No'] = pd.to_numeric(df_clean['No'], errors='coerce')

# Bersihkan kolom teks
text_columns = df_clean.select_dtypes(include='object').columns
df_clean[text_columns] = df_clean[text_columns].apply(lambda s: s.astype(str).str.strip())
df_clean.replace('', 'No Data', inplace=True)

# Konversi kolom kategorikal jika ada
categorical_cols = [
    'Checker', 'ASI/AFI', 'Status',
    'Efektif', 'Kejelasan Suara', 'Suara Lain',
    'Kelengkapan Rekaman', 'Sampling user side',
    'Hasil ASR', 'Hasil Pemeriksaan Kualitas', 'Agent Sampling'
]
for col in categorical_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype('category')

# Hapus kolom 'Status' jika ada
df_clean.drop(columns=['Status'], errors='ignore', inplace=True)

# Tampilkan info
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205344 entries, 0 to 205343
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   No                                205343 non-null  float64
#  1   Tanggal Pengerjaan                205344 non-null  datetime64[ns]
#  2   Checker                           205344 non-null  category
#  3   ASI/AFI                           205344 non-null  category
#  4   Waktu Inbound                     205344 non-null  datetime64[ns]
#  5   Nomor Inbound                     205344 non-null  object
#  6   Nama Agent                        205344 non-null  object
#  7   Call ID                           205344 non-null  object
#  8   Durasi Bicara                     205344 non-null  object
#  9   Detik                             205344 non-null  object
#  10  Total Tiket Riskan                205344 non-null  object
#  11  Apakah Riskan?                    205344 non-null  object
#  12  Tinjauan CS                       205344 non-null  object
#  13  Sampling user side                205344 non-null  category
#  14  Hasil Pemeriksaan Kualitas (old)  205344 non-null  object
#  15  Hasil ASR                         205344 non-null  category
#  16  Hasil Pemeriksaan Kualitas        205344 non-null  category
#  17  Efektif                           205344 non-null  category
#  18  Kejelasan Suara                   205344 non-null  category
#  19  Suara Lain                        205344 non-null  category
#  20  Kelengkapan Rekaman               205344 non-null  category
#  21  Agent Sampling                    205344 non-null  category
# dtypes: category(10), datetime64[ns](2), float64(1), object(9)
# memory usage: 20.8+ MB

# %%
df_clean
# Out:
#               No Tanggal Pengerjaan Checker ASI/AFI       Waktu Inbound  \
# 0            1.0         2025-03-10    Azer     ASI 2025-03-07 13:06:19
# 1            2.0         2025-03-10    Azer     ASI 2025-03-07 13:06:19
# 2            3.0         2025-03-10    Azer     ASI 2025-03-07 13:06:19
# 3            4.0         2025-03-10    Azer     ASI 2025-03-07 13:06:19
# 4            5.0         2025-03-10    Azer     ASI 2025-03-07 13:06:19
# ...          ...                ...     ...     ...                 ...
# 205339  205338.0         2025-11-10    Azer     ASI 2025-11-09 22:05:36
# 205340  205339.0         2025-11-10    Azer     ASI 2025-11-09 22:05:36
# 205341  205340.0         2025-11-10    Azer     ASI 2025-11-09 22:05:36
# 205342  205341.0         2025-11-10    Azer     ASI 2025-11-09 22:05:36
# 205343  205342.0         2025-11-10    Azer     ASI 2025-11-09 22:05:36
#
#          Nomor Inbound              Nama Agent  \
# 0         0812****7814  TCHL_Anindyka Alfisyah
# 1         0812****7814  TCHL_Anindyka Alfisyah
# 2         0812****7814  TCHL_Anindyka Alfisyah
# 3         0812****7814  TCHL_Anindyka Alfisyah
# 4         0812****7814  TCHL_Anindyka Alfisyah
# ...                ...                     ...
# 205339  0628******2801  Yulius Pandu Nusanjaya
# 205340  0628******2801  Yulius Pandu Nusanjaya
# 205341  0628******2801  Yulius Pandu Nusanjaya
# 205342  0628******2801  Yulius Pandu Nusanjaya
# 205343  0628******2801  Yulius Pandu Nusanjaya
#
#                                  Call ID Durasi Bicara                Detik  \
# 0       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:06:54
# 1       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:07:08
# 2       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:07:13
# 3       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:07:20
# 4       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:07:26
# ...                                  ...           ...                  ...
# 205339  a326139f635d4eae9e7d12be491e670a       0:05:23  2025-11-09 22:10:52
# 205340  a326139f635d4eae9e7d12be491e670a       0:05:23  2025-11-09 22:10:57
# 205341  a326139f635d4eae9e7d12be491e670a       0:05:23  2025-11-09 22:11:06
# 205342  a326139f635d4eae9e7d12be491e670a       0:05:23  2025-11-09 22:11:07
# 205343  a326139f635d4eae9e7d12be491e670a       0:05:23  2025-11-09 22:11:43
#
#         ... Tinjauan CS Sampling user side Hasil Pemeriksaan Kualitas (old)  \
# 0       ...     No Data               Done                          No Data
# 1       ...     No Data               Done                          No Data
# 2       ...     No Data               Done                          No Data
# 3       ...     No Data               Done                          No Data
# 4       ...     No Data               Done                          No Data
# ...     ...         ...                ...                              ...
# 205339  ...     No Data               Done                          No Data
# 205340  ...     No Data               Done                          No Data
# 205341  ...     No Data               Done                          No Data
# 205342  ...     No Data               Done                          No Data
# 205343  ...     No Data               Done                          No Data
#
#                  Hasil ASR Hasil Pemeriksaan Kualitas              Efektif  \
# 0             Entri Akurat          Percakapan Normal  Miss Target/ Not HC
# 1             Entri Akurat          Percakapan Normal  Miss Target/ Not HC
# 2       Terdapat kesalahan          Percakapan Normal  Miss Target/ Not HC
# 3       Terdapat kesalahan          Percakapan Normal  Miss Target/ Not HC
# 4       Terdapat kesalahan          Percakapan Normal  Miss Target/ Not HC
# ...                    ...                        ...                  ...
# 205339  Terdapat kesalahan          Percakapan Normal  Miss Target/ Not HC
# 205340        Entri Akurat          Percakapan Normal  Miss Target/ Not HC
# 205341  Terdapat kesalahan          Percakapan Normal  Miss Target/ Not HC
# 205342  Terdapat kesalahan          Percakapan Normal  Miss Target/ Not HC
# 205343        Entri Akurat          Percakapan Normal  Miss Target/ Not HC
#
#                                Kejelasan Suara              Suara Lain  \
# 0       Sangat jelas, tidak bising sama sekali        0 Satu pembicara
# 1       Sangat jelas, tidak bising sama sekali        0 Satu pembicara
# 2                                  Cukup Jelas  1 Suara tumpang tindih
# 3                                  Cukup Jelas        0 Satu pembicara
# 4                                  Cukup Jelas  1 Suara tumpang tindih
# ...                                        ...                     ...
# 205339  Sangat jelas, tidak bising sama sekali        0 Satu pembicara
# 205340  Sangat jelas, tidak bising sama sekali        0 Satu pembicara
# 205341  Sangat jelas, tidak bising sama sekali        0 Satu pembicara
# 205342  Sangat jelas, tidak bising sama sekali        0 Satu pembicara
# 205343  Sangat jelas, tidak bising sama sekali        0 Satu pembicara
#
#        Kelengkapan Rekaman Agent Sampling
# 0                   0 Utuh        No Data
# 1                   0 Utuh        No Data
# 2             1 Tidak Utuh        No Data
# 3                   0 Utuh        No Data
# 4                   0 Utuh        No Data
# ...                    ...            ...
# 205339        1 Tidak Utuh        No Data
# 205340              0 Utuh        No Data
# 205341        1 Tidak Utuh        No Data
# 205342        1 Tidak Utuh        No Data
# 205343              0 Utuh        No Data
#
# [205344 rows x 22 columns]

# %%
df_clean.to_csv('../../dataset_qc/new_4_clean.csv')
