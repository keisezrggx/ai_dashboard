# %%
import gspread
import pandas as pd
# from datetime import dates
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("LEMBAR KERJA - DISLIKE").worksheet("Sampling [dislike]")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../../raw_data/qc_kula.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118336 entries, 0 to 118335
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   0\                              118336 non-null  object
#  1   Score_date                      118336 non-null  object
#  2   Week                            118336 non-null  object
#  3   Month                           118336 non-null  object
#  4   QC Name                         118336 non-null  object
#  5   Business Type                   118336 non-null  object
#  6   Code                            118336 non-null  object
#  7   unsolved_num                    118336 non-null  object
#  8   FAQ Check                       118336 non-null  object
#  9   FAQ Status                      118336 non-null  object
#  10  Main Category                   118336 non-null  object
#  11  Checking Result (Sub Category)  118336 non-null  object
# ...

# %%
# Copy the df
df_clean = (
    df.copy()
    .iloc[:,[1,5,10,11,12,13]]
)

# Data type
df_clean['Score_date'] = pd.to_datetime(
    df_clean['Score_date'], errors='coerce'
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118336 entries, 0 to 118335
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Score_date                      118336 non-null  datetime64[ns]
#  1   Business Type                   118336 non-null  object
#  2   Main Category                   118336 non-null  object
#  3   Checking Result (Sub Category)  118336 non-null  object
#  4   Background detail- ID           118336 non-null  object
#  5   Team/Category                   118336 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 5.4+ MB

# %%
df_clean.to_csv('../../dataset_kula/qc_kula.csv')

# %%
df
# Out:
#                0\ Score_date Week        Month          QC Name Business Type  \
# 0       8/31/2023  8/28/2023       August 2023   Neneng Wahyuni           AFI
# 1       8/31/2023  8/28/2023       August 2023   Neneng Wahyuni           AFI
# 2       8/31/2023  8/28/2023       August 2023   Neneng Wahyuni           AFI
# 3       8/31/2023  8/28/2023       August 2023   Neneng Wahyuni           ASI
# 4       8/31/2023  8/28/2023       August 2023   Neneng Wahyuni           ASI
# ...           ...        ...  ...          ...              ...           ...
# 118331   6/8/2026   6/7/2026              June  Nurhamni Septia           ASI
# 118332   6/8/2026   6/7/2026              June  Nurhamni Septia           ASI
# 118333   6/8/2026   6/7/2026              June  Nurhamni Septia           ASI
# 118334   6/8/2026   6/7/2026              June  Nurhamni Septia           ASI
# 118335   6/8/2026   6/7/2026              June  Nurhamni Septia           ASI
#
# ...
