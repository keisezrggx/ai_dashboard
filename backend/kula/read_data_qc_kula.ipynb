# %%
import gspread
import pandas as pd
from datetime import date
from google.oauth2.service_account import Credentials
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("LEMBAR KERJA - DISLIKE").worksheet("Sampling [dislike]")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92705 entries, 0 to 92704
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Checking Date                   92705 non-null  object
#  1   Score_date                      92705 non-null  object
#  2   Week                            92705 non-null  object
#  3   Month                           92705 non-null  object
#  4   QC Name                         92705 non-null  object
#  5   Business Type                   92705 non-null  object
#  6   Code                            92705 non-null  object
#  7   unsolved_num                    92705 non-null  object
#  8   FAQ Check                       92705 non-null  object
#  9   FAQ Status                      92705 non-null  object
#  10  Main Category                   92705 non-null  object
#  11  Checking Result (Sub Category)  92705 non-null  object
#  12  Background detail- ID           92705 non-null  object
#  13  Team/Category                   92705 non-null  object
#  14  Type System Checking            92705 non-null  object
#  15  Chat ID                         92705 non-null  object
#  16  Result Analyze                  92705 non-null  object
#  17  Review FAQ                      92705 non-null  object
#  18  Review FAQ [Status]             92705 non-null  object
#  19  Online in Robot's               92705 non-null  object
#  20  Team QC                         92705 non-null  object
# dtypes: object(21)
# memory usage: 14.9+ MB

# %%
# Copy the df
df_clean = (
    df.copy()
    .iloc[:,[1,5,10,11,12,13]]
)

# Data type
df_clean['Score_date'] = pd.to_datetime(
    df_clean['Score_date'], errors='coerce'
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92705 entries, 0 to 92704
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Score_date                      92705 non-null  datetime64[ns]
#  1   Business Type                   92705 non-null  object
#  2   Main Category                   92705 non-null  object
#  3   Checking Result (Sub Category)  92705 non-null  object
#  4   Background detail- ID           92705 non-null  object
#  5   Team/Category                   92705 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 4.2+ MB

# %%
df_clean.to_csv('../../dataset_kula/qc_kula.csv')
