# %%
import gspread
import pandas as pd
from datetime import date
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("LEMBAR KERJA - DISLIKE").worksheet("Sampling [dislike]")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../../raw_data/qc_kula.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102612 entries, 0 to 102611
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Checking Date                   102612 non-null  object
#  1   Score_date                      102612 non-null  object
#  2   Week                            102612 non-null  object
#  3   Month                           102612 non-null  object
#  4   QC Name                         102612 non-null  object
#  5   Business Type                   102612 non-null  object
#  6   Code                            102612 non-null  object
#  7   unsolved_num                    102612 non-null  object
#  8   FAQ Check                       102612 non-null  object
#  9   FAQ Status                      102612 non-null  object
#  10  Main Category                   102612 non-null  object
#  11  Checking Result (Sub Category)  102612 non-null  object
#  12  Background detail- ID           102612 non-null  object
#  13  Team/Category                   102612 non-null  object
#  14  Type System Checking            102612 non-null  object
#  15  Chat ID                         102612 non-null  object
#  16  Result Analyze                  102612 non-null  object
#  17  Review FAQ                      102612 non-null  object
#  18  Review FAQ [Status]             102612 non-null  object
#  19  Online in Robot's               102612 non-null  object
#  20  Team QC                         102612 non-null  object
# dtypes: object(21)
# memory usage: 16.4+ MB

# %%
# Copy the df
df_clean = (
    df.copy()
    .iloc[:,[1,5,10,11,12,13]]
)

# Data type
df_clean['Score_date'] = pd.to_datetime(
    df_clean['Score_date'], errors='coerce'
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102612 entries, 0 to 102611
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Score_date                      102612 non-null  datetime64[ns]
#  1   Business Type                   102612 non-null  object
#  2   Main Category                   102612 non-null  object
#  3   Checking Result (Sub Category)  102612 non-null  object
#  4   Background detail- ID           102612 non-null  object
#  5   Team/Category                   102612 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 4.7+ MB

# %%
df_clean.to_csv('../../dataset_kula/qc_kula.csv')

# %%
df
# Out:
#        Checking Date Score_date Week        Month          QC Name  \
# 0          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 1          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 2          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 3          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 4          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# ...              ...        ...  ...          ...              ...
# 102607     2/27/2026  2/26/2026          February  Nurhamni Septia
# 102608     2/27/2026  2/26/2026          February  Nurhamni Septia
# 102609     2/27/2026  2/26/2026          February  Nurhamni Septia
# 102610     2/27/2026  2/26/2026          February  Nurhamni Septia
# 102611     2/27/2026  2/26/2026          February  Nurhamni Septia
#
#        Business Type               Code unsolved_num         FAQ Check  \
# 0                AFI              52926            1  checked, correct
# 1                AFI             210146            2  checked, correct
# 2                AFI             210149            2  checked, correct
# 3                ASI             210153            3  checked, correct
# 4                ASI             210164            2  checked, correct
# ...              ...                ...          ...               ...
# 102607           ASI    289-424-581-778           12  checked, correct
# 102608           ASI  289-1562-1563-943            1  checked, correct
# 102609           ASI  289-1527-1528-922            1  checked, correct
# 102610           ASI        1-13-53-338            1  checked, correct
# 102611           ASI    289-424-581-778            1  checked, correct
#
#          FAQ Status  ... Checking Result (Sub Category)  \
# 0       Not changed  ...           Not meet expectation
# 1       Not changed  ...           Not meet expectation
# 2       Not changed  ...           Not meet expectation
# 3       Not changed  ...           Not meet expectation
# 4       Not changed  ...           Not meet expectation
# ...             ...  ...                            ...
# 102607  Not changed  ...           Not meet expectation
# 102608  Not changed  ...           Not meet expectation
# 102609  Not changed  ...           Not meet expectation
# 102610  Not changed  ...           Not meet expectation
# 102611  Not changed  ...           Not meet expectation
#
#                             Background detail- ID  \
# 0       Check the remaining installment fund bill
# 1                Credit limit is less than income
# 2                Optional tenor akulaku paylatter
# 3                      Sell ​​products in Akulaku
# 4               How to use a voucher/coupon piece
# ...                                           ...
# 102607               Loan application is rejected
# 102608                         loan limit reduced
# 102609                  Help ACC loan application
# 102610         Shipping status is not appropriate
# 102611               Loan application is rejected
#
#                             Team/Category Type System Checking  \
# 0                                    Loan            [dislike]
# 1       Submission of Limit/Credit Points            [dislike]
# 2                        Akulaku Paylater            [dislike]
# 3                         Merchant Online            [dislike]
# 4                                 Voucher            [dislike]
# ...                                   ...                  ...
# 102607                               Loan
# 102608                               Loan
# 102609                               Loan
# 102610                    Merchant Online
# 102611                               Loan
#
#                             Chat ID  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...
# 102607  2-2057439402-3-1_1772052852
# 102608  2-2050650208-3-1_1772086975
# 102609  2-2023358297-3-1_1772102582
# 102610     2-3794383-3-1_1772068931
# 102611  2-2047150132-3-1_1772050666
#
#                                            Result Analyze Review FAQ  \
# 0       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 1                                                                 No
# 2       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 3       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 4       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# ...                                                   ...        ...
# 102607                               Jawaban sudah sesuai
# 102608                               Jawaban sudah sesuai
# 102609                               Jawaban sudah sesuai
# 102610                               Jawaban sudah sesuai
# 102611                               Jawaban sudah sesuai
#
#        Review FAQ [Status] Online in Robot's Team QC
# 0                                                ASI
# 1                                                ASI
# 2                                                ASI
# 3                                                ASI
# 4                                                ASI
# ...                    ...               ...     ...
# 102607                                           ASI
# 102608                                           ASI
# 102609                                           ASI
# 102610                                           ASI
# 102611                                           ASI
#
# [102612 rows x 21 columns]
