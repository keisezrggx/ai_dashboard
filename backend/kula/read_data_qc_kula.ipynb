# %%
import gspread
import pandas as pd
from datetime import date
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("LEMBAR KERJA - DISLIKE").worksheet("Sampling [dislike]")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90114 entries, 0 to 90113
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Checking Date                   90114 non-null  object
#  1   Score_date                      90114 non-null  object
#  2   Week                            90114 non-null  object
#  3   Month                           90114 non-null  object
#  4   QC Name                         90114 non-null  object
#  5   Business Type                   90114 non-null  object
#  6   Code                            90114 non-null  object
#  7   unsolved_num                    90114 non-null  object
#  8   FAQ Check                       90114 non-null  object
#  9   FAQ Status                      90114 non-null  object
#  10  Main Category                   90114 non-null  object
#  11  Checking Result (Sub Category)  90114 non-null  object
#  12  Background detail- ID           90114 non-null  object
#  13  Team/Category                   90114 non-null  object
#  14  Type System Checking            90114 non-null  object
#  15  Chat ID                         90114 non-null  object
#  16  Result Analyze                  90114 non-null  object
#  17  Review FAQ                      90114 non-null  object
#  18  Review FAQ [Status]             90114 non-null  object
#  19  Online in Robot's               90114 non-null  object
#  20  Team QC                         90114 non-null  object
# dtypes: object(21)
# memory usage: 14.4+ MB

# %%
# Copy the df
df_clean = (
    df.copy()
    .iloc[:,[1,5,10,11,12,13]]
)

# Data type
df_clean['Score_date'] = pd.to_datetime(
    df_clean['Score_date'], errors='coerce'
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90114 entries, 0 to 90113
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Score_date                      90114 non-null  datetime64[ns]
#  1   Business Type                   90114 non-null  object
#  2   Main Category                   90114 non-null  object
#  3   Checking Result (Sub Category)  90114 non-null  object
#  4   Background detail- ID           90114 non-null  object
#  5   Team/Category                   90114 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 4.1+ MB

# %%
df_clean.to_csv('../../dataset_kula/qc_kula.csv')
