# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials

# %% [markdown]
# ### File A

# %%
SERVICE_ACCOUNT_FILE = '../key/Credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("sample_3-1-robot").worksheet('sample 质检')
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../dataset_wellbore/sample_3-1-robot2.csv')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df
# Out:
#                        Rating Guides  \
# 0
# 1
# 2     Data_Date_Range  Checking_Date
# 3     May 19 - May 26     05/29/2026
# 4     May 19 - May 26     05/29/2026
# ...               ...            ...
# 2287                      07/10/2026
# 2288                      07/10/2026
# 2289                      07/10/2026
# 2290                      07/10/2026
# 2291                      07/10/2026
#
#      1 Jawaban tidak sesuai, tidak natural, dan opsi yang diberikan tidak sesuai  \
# 0     2 Jawaban tidak sesuai, tetapi opsi yang diber...
# 1     3 Jawaban dan opsi sudah sesuai, tetapi respon...
# 2                                             Model 机器人
# 3                                             3-1-robot
# 4                                             3-1-robot
# ...                                                 ...
# 2287                                         3-1-robot2
# 2288                                         3-1-robot2
# 2289                                         3-1-robot2
# 2290                                         3-1-robot2
# 2291                                         3-1-robot2
#
#                                                                     \
# 0
# 1
# 2                         Chat ID  Validator 审核员         Result 结果
# 3      2-117478928-3-1_1779268396            Aul  Correct Response
# 4      2-122276817-3-1_1779512825            Aul  Correct Response
# ...                           ...            ...               ...
# 2287  2-2044131443-3-1_1783329278           Reza  Correct Response
# 2288    2-20597810-3-1_1783295712           Reza  Correct Response
# 2289     2-4266520-3-1_1783436331           Reza  Correct Response
# 2290  2-2060208710-3-1_1783303007           Reza  Correct Response
# 2291  2-2061247921-3-1_1783311307           Reza  Correct Response
#
#      4 Jawaban sesuai dan tidak ada opsi yang diberikan, namun respon terdengar tidak natural  \
# 0     5 Jawaban sesuai dan terdengar natural, serta ...
# 1
# 2                                     Overall Rating 评分
# 3                                                     3
# 4                                                     3
# ...                                                 ...
# 2287                                                  5
# 2288                                                  5
# 2289                                                  5
# 2290                                                  5
# 2291                                                  5
#
#                                                                                \
# 0
# 1
# 2                                         Pain Point 痛点  Supposed Response
# 3     Kula langsung memberikan opsi dan jawaban dari...
# 4     Kula langsung memberikan opsi dan jawaban dari...                     1
# ...                                                 ...                ... ..
# 2287
# 2288
# 2289
# 2290
# 2291
#
#
# 0
# 1
# 2
# 3
# 4
# ...  .. ..
# 2287
# 2288
# 2289
# 2290
# 2291
#
# [2292 rows x 12 columns]

# %% [markdown]
# ### File B

# %%
df_high_risk = pd.read_csv('../dataset_wellbore/high_risk_20260701.csv')
df_high_risk
# Out:
#         行号                                           msg_text  \
# 0        2  udah lah klu emang g dapet dah gpp cape² sy un...
# 1        3  sya viralkan sjh ini aplikasi biar tdak ad yan...
# 2        4           sy bntu viral kn biar tdak ad yang pakai
# 3        5  sy viralkan ini aplikasi biar tdak ad yng paka...
# 4        6                        Akan saya viral ini akulaku
# ...    ...                                                ...
# 1992  2094                                         biar viral
# 1993  2095                      mau saya viralkan ini akulaku
# 1994  2096  klau tidak di acc saya viralkan toko nya dan a...
# 1995  2097  UNTUK POSTINGAN DI MEDIA SOSIAL SUDAH SAYA POS...
# 1996  2098  UNTUK LAMAN DI MEDIA SOSIAL SUDAH SAYA POST IN...
#
#               old_model     new_model                人工打标结果  \
# 0     keluhan di tempat        normal   {"value": "normal"}
# 1               keluhan  ulasan buruk  {"value": "keluhan"}
# 2               keluhan  ulasan buruk  {"value": "keluhan"}
# 3               keluhan  ulasan buruk  {"value": "keluhan"}
# 4               keluhan  ulasan buruk  {"value": "keluhan"}
# ...                 ...           ...                   ...
# 1992            keluhan  ulasan buruk  {"value": "keluhan"}
# 1993            keluhan  ulasan buruk  {"value": "keluhan"}
# 1994            keluhan        normal  {"value": "keluhan"}
# 1995            keluhan  ulasan buruk  {"value": "keluhan"}
# 1996            keluhan        normal  {"value": "keluhan"}
#
#                                                      备注  \
# 0     Tidak ada kata HC yang disebutkan customer nam...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1992                                                NaN
# 1993                                                NaN
# 1994                                                NaN
# 1995                                                NaN
# 1996                                                NaN
#
#                         打标人                 打标时间            LLM打标结果  \
# 0     Muhammad Reza Mauladi  2026-07-03 07:58:51      ketidakpuasan
# 1     Muhammad Reza Mauladi  2026-07-03 07:58:51       ulasan buruk
# 2     Muhammad Reza Mauladi  2026-07-03 07:58:51       ulasan buruk
# 3     Muhammad Reza Mauladi  2026-07-03 07:58:51            keluhan
# 4     Muhammad Reza Mauladi  2026-07-03 07:58:51            keluhan
# ...                     ...                  ...                ...
# 1992         Aulia Az-Zahra  2026-07-10 02:17:28             normal
# 1993         Aulia Az-Zahra  2026-07-10 02:17:28  keluhan di tempat
# 1994         Aulia Az-Zahra  2026-07-10 02:17:28            keluhan
# 1995         Aulia Az-Zahra  2026-07-10 02:17:28             normal
# 1996         Aulia Az-Zahra  2026-07-10 02:17:28             normal
#
#             LLM模型              LLM打标时间       状态 old_model_vs人工 new_model_vs人工  \
# 0     deepseek-v3  2026-07-02 10:33:31  labeled              否              是
# 1     deepseek-v3  2026-07-02 10:33:35  labeled              是              否
# 2     deepseek-v3  2026-07-02 10:33:39  labeled              是              否
# 3     deepseek-v3  2026-07-02 10:33:43  labeled              是              否
# 4     deepseek-v3  2026-07-02 10:33:47  labeled              是              否
# ...           ...                  ...      ...            ...            ...
# 1992  deepseek-v3  2026-07-02 13:09:49  labeled              是              否
# 1993  deepseek-v3  2026-07-02 13:09:56  labeled              是              否
# 1994  deepseek-v3  2026-07-02 13:10:00  labeled              是              否
# 1995  deepseek-v3  2026-07-02 13:10:04  labeled              是              否
# 1996  deepseek-v3  2026-07-02 13:10:10  labeled              是              否
#
#      old_model_vsLLM new_model_vsLLM
# 0                  否               否
# 1                  否               是
# 2                  否               是
# 3                  是               否
# 4                  是               否
# ...              ...             ...
# 1992               否               否
# 1993               否               否
# 1994               是               否
# 1995               否               否
# 1996               否               是
#
# [1997 rows x 16 columns]
