# %%
import gspread
import pandas as pd
# from datetime import dates
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("LEMBAR KERJA - DISLIKE").worksheet("Sampling [dislike]")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../../raw_data/qc_kula.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119683 entries, 0 to 119682
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Checking Date                   119683 non-null  object
#  1   Score_date                      119683 non-null  object
#  2   Week                            119683 non-null  object
#  3   Month                           119683 non-null  object
#  4   QC Name                         119683 non-null  object
#  5   Business Type                   119683 non-null  object
#  6   Code                            119683 non-null  object
#  7   unsolved_num                    119683 non-null  object
#  8   FAQ Check                       119683 non-null  object
#  9   FAQ Status                      119683 non-null  object
#  10  Main Category                   119683 non-null  object
#  11  Checking Result (Sub Category)  119683 non-null  object
#  12  Background detail- ID           119683 non-null  object
#  13  Team/Category                   119683 non-null  object
#  14  Chat ID                         119683 non-null  object
#  15  Result Analyze                  119683 non-null  object
#  16  Review FAQ                      119683 non-null  object
#  17  Review FAQ [Status]             119683 non-null  object
#  18  Online in Robot's               119683 non-null  object
#  19  Team QC                         119683 non-null  object
# dtypes: object(20)
# memory usage: 18.3+ MB

# %%
# Copy the df
df_clean = (
    df.copy()
    .iloc[:,[1,5,10,11,12,13]]
)

# Data type
df_clean['Score_date'] = pd.to_datetime(
    df_clean['Score_date'], errors='coerce'
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119683 entries, 0 to 119682
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Score_date                      119683 non-null  datetime64[ns]
#  1   Business Type                   119683 non-null  object
#  2   Main Category                   119683 non-null  object
#  3   Checking Result (Sub Category)  119683 non-null  object
#  4   Background detail- ID           119683 non-null  object
#  5   Team/Category                   119683 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 5.5+ MB

# %%
df_clean.to_csv('../../dataset_kula/qc_kula.csv')

# %%
df
# Out:
#        Checking Date Score_date Week        Month          QC Name  \
# 0          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 1          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 2          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 3          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 4          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# ...              ...        ...  ...          ...              ...
# 119678     6/22/2026  6/21/2026              June  Nurhamni Septia
# 119679     6/22/2026  6/21/2026              June  Nurhamni Septia
# 119680     6/22/2026  6/21/2026              June  Nurhamni Septia
# 119681     6/22/2026  6/21/2026              June  Nurhamni Septia
# 119682     6/22/2026  6/19/2026              June  Nurhamni Septia
#
#        Business Type                Code unsolved_num         FAQ Check  \
# 0                AFI               52926            1  checked, correct
# 1                AFI              210146            2  checked, correct
# 2                AFI              210149            2  checked, correct
# 3                ASI              210153            3  checked, correct
# 4                ASI              210164            2  checked, correct
# ...              ...                 ...          ...               ...
# 119678           ASI     289-369-526-777            3  checked, correct
# 119679           ASI     289-424-581-778            3  checked, correct
# 119680           ASI  289-1728-1729-1167            1  checked, correct
# 119681           ASI  1210-1216-1262-156            1  checked, correct
# 119682           ASI  1134-1156-1179-807            1  checked, correct
#
#          FAQ Status Main Category Checking Result (Sub Category)  \
# 0       Not changed      Customer           Not meet expectation
# 1       Not changed      Customer           Not meet expectation
# 2       Not changed      Customer           Not meet expectation
# 3       Not changed      Customer           Not meet expectation
# 4       Not changed      Customer           Not meet expectation
# ...             ...           ...                            ...
# 119678  Not changed      Customer           Not meet expectation
# 119679  Not changed      Customer           Not meet expectation
# 119680  Not changed      Customer           Not meet expectation
# 119681  Not changed      Customer           Not meet expectation
# 119682  Not changed      Customer           Not meet expectation
#
#                             Background detail- ID  \
# 0       Check the remaining installment fund bill
# 1                Credit limit is less than income
# 2                Optional tenor akulaku paylatter
# 3                      Sell ​​products in Akulaku
# 4               How to use a voucher/coupon piece
# ...                                           ...
# 119678                    Cannot apply for a loan
# 119679               Loan application is rejected
# 119680                Cash loans are not possible
# 119681             Refund funds have not returned
# 119682       Changes to missing telephone numbers
#
#                             Team/Category                      Chat ID  \
# 0                                    Loan
# 1       Submission of Limit/Credit Points
# 2                        Akulaku Paylater
# 3                         Merchant Online
# 4                                 Voucher
# ...                                   ...                          ...
# 119678                               Loan    2-20669862-3-1_1781893483
# 119679                               Loan    2-57730372-3-1_1781894112
# 119680                               Loan  2-2024674897-3-1_1782021459
# 119681                             Refund     2-6298068-3-1_1782008206
# 119682                        Data Update  2-2061012083-3-1_1781881924
#
#                                            Result Analyze Review FAQ  \
# 0       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 1                                                                 No
# 2       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 3       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 4       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# ...                                                   ...        ...
# 119678                               Jawaban sudah sesuai
# 119679                               Jawaban sudah sesuai
# 119680                               Jawaban sudah sesuai
# 119681                               Jawaban sudah sesuai
# 119682                               Jawaban sudah sesuai
#
#        Review FAQ [Status] Online in Robot's Team QC
# 0                                              #REF!
# 1
# 2
# 3
# 4
# ...                    ...               ...     ...
# 119678
# 119679
# 119680
# 119681
# 119682
#
# [119683 rows x 20 columns]
