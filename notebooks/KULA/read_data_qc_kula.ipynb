# %%
import gspread
import pandas as pd
# from datetime import dates
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("LEMBAR KERJA - DISLIKE").worksheet("Sampling [dislike]")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../../raw_data/qc_kula.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121287 entries, 0 to 121286
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Checking Date                   121287 non-null  object
#  1   Score_date                      121287 non-null  object
#  2   Week                            121287 non-null  object
#  3   Month                           121287 non-null  object
#  4   QC Name                         121287 non-null  object
#  5   Business Type                   121287 non-null  object
#  6   Code                            121287 non-null  object
#  7   unsolved_num                    121287 non-null  object
#  8   FAQ Check                       121287 non-null  object
#  9   FAQ Status                      121287 non-null  object
#  10  Main Category                   121287 non-null  object
#  11  Checking Result (Sub Category)  121287 non-null  object
#  12  Background detail- ID           121287 non-null  object
#  13  Team/Category                   121287 non-null  object
#  14  Chat ID                         121287 non-null  object
#  15  Result Analyze                  121287 non-null  object
#  16  Review FAQ                      121287 non-null  object
#  17  Review FAQ [Status]             121287 non-null  object
#  18  Online in Robot's               121287 non-null  object
#  19  Team QC                         121287 non-null  object
# dtypes: object(20)
# memory usage: 18.5+ MB

# %%
# Copy the df
df_clean = (
    df.copy()
    .iloc[:,[1,5,10,11,12,13]]
)

# Data type
df_clean['Score_date'] = pd.to_datetime(
    df_clean['Score_date'], errors='coerce'
)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121287 entries, 0 to 121286
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Score_date                      121287 non-null  datetime64[ns]
#  1   Business Type                   121287 non-null  object
#  2   Main Category                   121287 non-null  object
#  3   Checking Result (Sub Category)  121287 non-null  object
#  4   Background detail- ID           121287 non-null  object
#  5   Team/Category                   121287 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 5.6+ MB

# %%
df_clean.to_csv('../../dataset_kula/qc_kula.csv')

# %%
df
# Out:
#        Checking Date Score_date Week        Month          QC Name  \
# 0          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 1          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 2          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 3          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# 4          8/31/2023  8/28/2023       August 2023   Neneng Wahyuni
# ...              ...        ...  ...          ...              ...
# 121282      7/8/2026   7/7/2026              July  Nurhamni Septia
# 121283      7/8/2026   7/7/2026              July  Nurhamni Septia
# 121284      7/8/2026   7/7/2026              July  Nurhamni Septia
# 121285      7/8/2026   7/7/2026              July  Nurhamni Septia
# 121286      7/8/2026   7/7/2026              July  Nurhamni Septia
#
#        Business Type             Code unsolved_num         FAQ Check  \
# 0                AFI            52926            1  checked, correct
# 1                AFI           210146            2  checked, correct
# 2                AFI           210149            2  checked, correct
# 3                ASI           210153            3  checked, correct
# 4                ASI           210164            2  checked, correct
# ...              ...              ...          ...               ...
# 121282           ASI  289-364-521-570            1  checked, correct
# 121283           ASI  289-308-465-411            1  checked, correct
# 121284           ASI      1-23-67-502            1  checked, correct
# 121285           ASI  289-423-580-772            1  checked, correct
# 121286           ASI  289-384-541-626            1  checked, correct
#
#          FAQ Status Main Category Checking Result (Sub Category)  \
# 0       Not changed      Customer           Not meet expectation
# 1       Not changed      Customer           Not meet expectation
# 2       Not changed      Customer           Not meet expectation
# 3       Not changed      Customer           Not meet expectation
# 4       Not changed      Customer           Not meet expectation
# ...             ...           ...                            ...
# 121282  Not changed      Customer           Not meet expectation
# 121283  Not changed      Customer           Not meet expectation
# 121284  Not changed      Customer           Not meet expectation
# 121285  Not changed      Customer           Not meet expectation
# 121286  Not changed      Customer           Not meet expectation
#
#                             Background detail- ID  \
# 0       Check the remaining installment fund bill
# 1                Credit limit is less than income
# 2                Optional tenor akulaku paylatter
# 3                      Sell ​​products in Akulaku
# 4               How to use a voucher/coupon piece
# ...                                           ...
# 121282          Loan funds have not been received
# 121283                       Loan limit decreases
# 121284              How to add a shipping address
# 121285     On time paying loans, but can't borrow
# 121286                How to check the loan limit
#
#                             Team/Category                      Chat ID  \
# 0                                    Loan
# 1       Submission of Limit/Credit Points
# 2                        Akulaku Paylater
# 3                         Merchant Online
# 4                                 Voucher
# ...                                   ...                          ...
# 121282                               Loan  2-2061594969-3-1_1783412241
# 121283                               Loan  2-2037616186-3-1_1783412030
# 121284                    Merchant Online  2-2034811363-3-1_1783432637
# 121285                               Loan    2-17958189-3-1_1783423705
# 121286                               Loan   2-112932934-3-1_1783404284
#
#                                            Result Analyze Review FAQ  \
# 0       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 1                                                                 No
# 2       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 3       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# 4       Pelanggan telah klik pertanyaan sesuai dengan ...         No
# ...                                                   ...        ...
# 121282                               Jawaban sudah sesuai
# 121283                               Jawaban sudah sesuai
# 121284                               Jawaban sudah sesuai
# 121285                               Jawaban sudah sesuai
# 121286                               Jawaban sudah sesuai
#
#        Review FAQ [Status] Online in Robot's Team QC
# 0                                                ASI
# 1                                                ASI
# 2                                                ASI
# 3                                                ASI
# 4                                                ASI
# ...                    ...               ...     ...
# 121282                                           ASI
# 121283                                           ASI
# 121284                                           ASI
# 121285                                           ASI
# 121286                                           ASI
#
# [121287 rows x 20 columns]
