# %%
import pandas as pd

# %%
df_task = pd.read_csv(
    '../dataset_wellbore/包含 1500920的话术 - 工作表1.csv'
)

df_dataset = pd.read_csv(
    '../dataset_wellbore/NEW Akulaku - AI Kula Scene Classification (2025) - NEW 12.14.csv'
)

# %%
df_task
# Out:
#                  code                               Background_Detail_ID  \
# 0         1-11-47-271           [Global Buy] Produk hilang di jasa kirim
# 1         1-11-48-864                        Produk hilang di jasa kirim
# 2         1-11-49-865        Produk hilang di jasa kirim produk official
# 3         1-14-56-867  Transaksi berhasil namun belum diterima produk...
# 4         1-24-68-771  Kenapa sudah melakukan pembayaran Dp, pesanan ...
# ..                ...                                                ...
# 236  872-948-1043-759                 Pelunasan semua tagihan Dana Cicil
# 237  872-954-1049-804               Barang sudah diretur, tagihan muncul
# 238  872-955-1050-806                          Tagihan PDAM masih muncul
# 239  872-958-1053-828         Pembayaran gagal, saldo rekening terpotong
# 240  872-962-1057-879      Tidak muncul Virtual Account tagihan Pinjaman
#
#                                             ID_Example  New_Answer   是否修改  \
# 0    Bagaimana jika produk Global Buy hilang di jas...         NaN  是 Yes
# 1    Bagaimana jika produk Merchant Online hilang d...         NaN  是 Yes
# 2    Bagaimana jika produk Produk Official Store hi...         NaN  是 Yes
# 3    Bagaimana jika status pesanan Produk Official ...         NaN  是 Yes
# 4    Kenapa DP sudah bayar kok barang tidak jadi di...         NaN  是 Yes
# ..                                                 ...         ...    ...
# 236  Bagaimana metode pembayaran jika ingin melunas...         NaN    NaN
# 237  Kenapa tagihan masih muncul padahal sudah pros...         NaN    NaN
# 238  Kenapa tagihan PDAM masih muncul, padahal suda...         NaN    NaN
# 239  Apa yang harus dilakukan jika menemukan kendal...         NaN    NaN
# 240  Tolong dibantu saya mau melunasi pinjaman Dana...         NaN    NaN
#
#      新的code（code不变不需要填写） Validator Test Pass? Error Note
# 0                    NaN     Hamni      是 Yes        NaN
# 1                    NaN     Hamni      是 Yes        NaN
# 2                    NaN     Hamni      是 Yes        NaN
# 3                    NaN     Hamni      是 Yes        NaN
# 4                    NaN     Hamni      是 Yes        NaN
# ..                   ...       ...        ...        ...
# 236                  NaN       NaN        NaN        NaN
# 237                  NaN       NaN        NaN        NaN
# 238                  NaN       NaN        NaN        NaN
# 239                  NaN       NaN        NaN        NaN
# 240                  NaN       NaN        NaN        NaN
#
# [241 rows x 9 columns]

# %%
df_dataset
# Out:
#     Unnamed: 0   No Create Time Classification Business FAQ Status OLD Code  \
# 0          无更新    1   12/1/2022                     ASI     Online   130101
# 1          无更新    2   12/1/2022                     ASI     Online   180101
# 2          无更新    3   12/1/2022                     ASI     Online    31001
# 3          无更新    4   12/1/2022                     ASI     Online   131601
# 4          无更新    5   12/1/2022                     AFI     Online    70401
# ..         ...  ...         ...                     ...        ...      ...
# 946        NaN  947         NaN                     AFI     Online      NaN
# 947        NaN  948         NaN                     AFI     Online      NaN
# 948        NaN  949         NaN                     ASI     Online      NaN
# 949        NaN  950         NaN                     ASI     Online      NaN
# 950        NaN  951         NaN                     ASI     Online      NaN
#
#                 New-Code 一级分类\nKategori 1 (CN) 分类（英）\nKategori 1 (EN)  \
# 0        794-795-809-117                   ETC                    ETC
# 1     1210-1211-1257-118                    退款                 Refund
# 2        597-598-609-119                    保险              Insurance
# 3             1-2-28-120                    物流              Logistics
# 4        738-739-758-121                  帐户安全       Account security
# ..                   ...                   ...                    ...
# 946  1321-1912-1913-1261                  SLIK                   SLIK
# 947  1321-1914-1915-1262                  SLIK                   SLIK
# 948  1321-1916-1917-1264                  SLIK                   SLIK
# 949  1321-1918-1919-1265                  SLIK                   SLIK
# 950  1321-1920-1921-1266                  SLIK                   SLIK
#
#     分类（印尼）\nKategori 1 (ID)  ...  \
# 0                 Lain-Lain  ...
# 1                    Refund  ...
# 2                  Asuransi  ...
# 3                  Logistik  ...
# 4             Keamanan Akun  ...
# ..                      ...  ...
# 946                    SLIK  ...
# 947                    SLIK  ...
# 948                    SLIK  ...
# 949                    SLIK  ...
# 950                    SLIK  ...
#
#                                           NEW - ANSWER Wordcounter  \
# 0    Mohon maaf untuk jenis permasalahan ini memerl...         NaN
# 1    Jika Kakak sudah sukses melakukan pembayaran n...         NaN
# 2    Kakak bisa melakukan pengecekan terlebih dahul...         NaN
# 3    Jika pihak penjual meminta biaya tambahan ongk...         NaN
# 4    Kula bantu informasikan bahwa setelah Kakak me...         NaN
# ..                                                 ...         ...
# 946                                                NaN         NaN
# 947                                                NaN         NaN
# 948                                                NaN         NaN
# 949                                                NaN         NaN
# 950                                                NaN         NaN
#
#                                                    回复2                  需求  \
# 0                                     转人工// alihkan CS                 NaN
# 1     已有卡片 【申请退款】//\nsudah ada klasifikasi ttg refund                  NaN
# 2                                                  ASI                 NaN
# 3    已有卡片 【物流轨迹卡】// sudah ada klasifikasi ttg pengi...                 NaN
# 4                                                  AFI  加安全中心卡片【临时冻结，永久冻结】
# ..                                                 ...                 ...
# 946                                                NaN                 NaN
# 947                                                NaN                 NaN
# 948                                                NaN                 NaN
# 949                                                NaN                 NaN
# 950                                                NaN                 NaN
#
#            ID\n(P1 Plan: Poin 2) Explanation Update / Revision  FAQ Date  \
# 0        transferred to CS (转人工）   Old 10.13                24 July 2024
# 1    finished by chatbot (机器人解决）   Old 10.13             2 November 2023
# 2    finished by chatbot (机器人解决）   Old 10.13             2 November 2023
# 3    finished by chatbot (机器人解决）   Old 10.13             2 November 2023
# 4    finished by chatbot (机器人解决）   Old 10.13               22 April 2025
# ..                           ...         ...                         ...
# 946  finished by chatbot (机器人解决）         NaN                         NaN
# 947  finished by chatbot (机器人解决）         NaN                         NaN
# 948  finished by chatbot (机器人解决）         NaN                         NaN
# 949  finished by chatbot (机器人解决）         NaN                         NaN
# 950  finished by chatbot (机器人解决）         NaN                         NaN
#
#     Add Screenshot/GIFT Operator Update & Testing
# 0                   NaN      NaN              NaN
# 1                   NaN      NaN              NaN
# 2                   NaN      NaN              NaN
# 3                   NaN      NaN              NaN
# 4             SS & GIFT    Hamni             Done
# ..                  ...      ...              ...
# 946                 NaN      NaN              NaN
# 947                 NaN      NaN              NaN
# 948                 NaN      NaN              NaN
# 949                 NaN      NaN              NaN
# 950                 NaN      NaN              NaN
#
# [951 rows x 57 columns]

# %%
df_dataset[['New-Code','ID\n(P1 Plan: Poin 2)', 'NEW - ANSWER']]
# Out:
#                 New-Code        ID\n(P1 Plan: Poin 2)  \
# 0        794-795-809-117      transferred to CS (转人工）
# 1     1210-1211-1257-118  finished by chatbot (机器人解决）
# 2        597-598-609-119  finished by chatbot (机器人解决）
# 3             1-2-28-120  finished by chatbot (机器人解决）
# 4        738-739-758-121  finished by chatbot (机器人解决）
# ..                   ...                          ...
# 946  1321-1912-1913-1261  finished by chatbot (机器人解决）
# 947  1321-1914-1915-1262  finished by chatbot (机器人解决）
# 948  1321-1916-1917-1264  finished by chatbot (机器人解决）
# 949  1321-1918-1919-1265  finished by chatbot (机器人解决）
# 950  1321-1920-1921-1266  finished by chatbot (机器人解决）
#
#                                           NEW - ANSWER
# 0    Mohon maaf untuk jenis permasalahan ini memerl...
# 1    Jika Kakak sudah sukses melakukan pembayaran n...
# 2    Kakak bisa melakukan pengecekan terlebih dahul...
# 3    Jika pihak penjual meminta biaya tambahan ongk...
# 4    Kula bantu informasikan bahwa setelah Kakak me...
# ..                                                 ...
# 946                                                NaN
# 947                                                NaN
# 948                                                NaN
# 949                                                NaN
# 950                                                NaN
#
# [951 rows x 3 columns]
