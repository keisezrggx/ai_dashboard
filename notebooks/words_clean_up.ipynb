# %%
import pandas as pd

# %%
df = pd.read_csv('temp/ai语音数据 - Sheet1.csv')
df
# Out:
#                                       序号    QC  \
# 0    https://bit.ly/ai_qc_text_to_speech   NaN
# 1                                      1  Azer
# 2                                      2  Azer
# 3                                      3  Azer
# 4                                      4  Azer
# ..                                   ...   ...
# 469                                  469  Reza
# 470                                  470  Reza
# 471                                  471  Reza
# 472                                  472  Reza
# 473                                  473  Reza
#
#                                                   原始语音 Kalimat (fixed)  \
# 0                                                  NaN             NaN
# 1                         gak ada pemotongan bunga nya             NaN
# 2                                saya bayar nya tgl q8             NaN
# 3           kenapa saya tidak bisa mengajukan pinjaman             NaN
# ...

# %%
df_clean = df[1:]
df_clean
# Out:
#       序号    QC                                               原始语音  \
# 1      1  Azer                       gak ada pemotongan bunga nya
# 2      2  Azer                              saya bayar nya tgl q8
# 3      3  Azer         kenapa saya tidak bisa mengajukan pinjaman
# 4      4  Azer  kenapa saya tidak bisa melakukan melakukan pin...
# 5      5  Azer  kenapa saya tidak bisa melakukan pinjaman dana...
# ..   ...   ...                                                ...
# 469  469  Reza                                    isi puasa saya.
# 470  470  Reza  kenapa paylater saya tidak bisa digunakan,pada...
# 471  471  Reza                kenapa tidak ada layanan untuk bca?
# 472  472  Reza         Saya ingin membeli ponsel Apple warna biru
# 473  473  Reza                              i want to buy a phone
#
#     Kalimat (fixed) Intonasi Device
# 1               NaN      NaN    NaN
# 2               NaN      NaN    NaN
# 3               NaN      NaN    NaN
# ...
