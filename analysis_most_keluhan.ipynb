# %%
import pandas as pd

# %%
df = pd.read_csv('analysis_data/most_keluhan_akulaku_superset_presto_hanmm 1769063889.csv')
df.info()
# Out:
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_9004\676855241.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('analysis_data/most_keluhan_akulaku_superset_presto_hanmm 1769063889.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137739 entries, 0 to 137738
# Data columns (total 56 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   company                          137739 non-null  object
#  1   Aplication                       137739 non-null  object
#  2   UID                              136519 non-null  object
#  3   UserName                         137737 non-null  object
#  4   Phone Number                     137739 non-null  object
#  5   Ticket Type                      137739 non-null  object
#  6   Ticket complaint_type            130967 non-null  object
# ...

# %%
df
# Out:
#         company Aplication           UID  \
# 0       Akulaku        ASI  2047779496.0
# 1       Akulaku        ASI     9082822.0
# 2       Akulaku        ASI  2021752327.0
# 3       Akulaku        ASI  2041154732.0
# 4       Akulaku        ASI     9130203.0
# ...         ...        ...           ...
# 137734  Akulaku        ASI    2053029653
# 137735  Akulaku        ASI    2005199905
# 137736  Akulaku        ASI     102526328
# 137737  Akulaku        ASI    2040817994
# 137738  Akulaku        ASI      19777377
#
#                                                  UserName  \
# 0       AL$$_1_QYx1iYrgq2vQhr3kLu6P0xeL/Z/KTgHYxg8zbTD...
# 1       AL$$_1_YvE9VC9y5DTGQ91hmaCn878NeEBZpCQpcQ8rZm3...
# 2       AL$$_1_LTIqFqyOWGquTwtQ1Ir8/ji0m+ewnsYBdgKHQaU...
# 3       AL$$_1_ldShcV+2sjDla4yaNL7xFelf58SqgY7rnGVbeVb...
# 4       AL$$_1_dDE6rTgm7nE/WZuzstxhQQoTw5RoAEpefjxXgFh...
# ...                                                   ...
# ...

# %%
df.iloc[:,[15,17,18,19]]
# Out:
#                              Case Category                  Category1  \
# 0               Kendala Pengajuan Pinjaman                       Bugs
# 1                             Resi Invalid         3 Party Group Chat
# 2               Permintaan Kode Pembayaran    Dana Cicil (Large Loan)
# 3                          Gagal Pengajuan                        PDL
# 4        Informasi Terkait Limit Pinjaman                         PDL
# ...                                    ...                        ...
# 137734                     Gagal Pengajuan                        PDL
# 137735                      Informasi Umum  Informasi Umum & Feedback
# 137736       Pembayaran Belum Masuk Sistem                        PDL
# 137737                     Gagal Pengajuan                        PDL
# 137738  Informasi Terkait Proses Pengajuan    Dana Cicil (Large Loan)
#
#                               Category2                           Category3
# ...

# %%
df['Case Category'].value_counts()
# Out:
# Case Category
# Gagal Pengajuan                                   22379
# Transfer Call/Chat to AFI                         11746
# Informasi Terkait Pembayaran Pinjaman              9937
# Permintaan Kode Pembayaran                         6384
# Informasi Terkait Tagihan                          4881
#                                                   ...
# Opsi Pembayaran Tidak Muncul/Kendala - Danamon        1
# Double Pembayaran - Down Payment (DP)                 1
# Informasi Terkait Promo Produk Tunggal                1
# Special case Dana Cicil                               1
# Pembatalan Akulaku Protection Gadget                  1
# Name: count, Length: 229, dtype: int64

# %%
df['Category1'].value_counts()
# Out:
# Category1
# PDL                                  52676
# Dana Cicil (Large Loan)              24560
# Informasi Umum & Feedback            14844
# Transfer Call/Chat to AFI            11746
# 3 Party Group Chat                    5361
# Pengkinian Data                       4807
# Merchant Online                       4622
# Transfer Chat Ke ASI - E-Commerce     3459
# Dana Flexi                            3198
# Issue Refund Ticket New               3122
# Case Email                            2085
# Produk Virtual & Voucher              1901
# Bugs                                  1750
# Promo/Event                           1018
# Transfer Chat Ke ASI - Loan            682
# Keamanan Akun                          654
# Complaint Case New                     518
# Loan                                   448
# Tiket Pesawat                          108
# Refund (Tier 2)                         98
# CS Merchant Case                        56
# ...

# %%
df['Category2'].value_counts()
# Out:
# Category2
# Pengajuan Pinjaman                       40073
# Pembayaran & Tagihan (Pinjaman)          25751
# Collection                               12219
# Spam                                      6375
# Incomplete Details                        5685
#                                          ...
# Merchant Offline                             2
# Akulaku Goods Protection                     1
# Hapus Denda                                  1
# Double Pembayaran - Down Payment (DP)        1
# Promo Produk Tunggal                         1
# Name: count, Length: 64, dtype: int64

# %%
df['Category3'].value_counts()
# Out:
# Category3
# Gagal Pengajuan                                   22379
# Informasi Terkait Pembayaran Pinjaman              9937
# Permintaan Kode Pembayaran                         6384
# Informasi Terkait Tagihan                          4881
# Informasi Terkait Proses Pengajuan                 4516
#                                                   ...
# Opsi Pembayaran Tidak Muncul/Kendala - Danamon        1
# Pinjaman/Cash Loan/PDL/PayLater/OpenPay               1
# Informasi Terkait Promo Produk Tunggal                1
# Special case Dana Cicil                               1
# Pembatalan Akulaku Protection Gadget                  1
# Name: count, Length: 210, dtype: int64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# ...
