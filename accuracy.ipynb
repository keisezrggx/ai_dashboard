# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import pygwalker as pyg

# %%
df = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753329431_21.csv')
df_22 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753341756_22.csv')
df_28 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753775670_28.csv')
df_8_5 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1754385922_8_5.csv')
df_8_11 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1755661415_8_11.csv')
df_8_18 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1755661737_8_18.csv')
df_8_27 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1756259130_8_27.csv')
df_9_2 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1756871451_9_2.csv')
df_9_15 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1758096653_9_15.csv')
df_9_29 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1759370414_9_29.csv')
df_10_6 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1759824736_10_6.csv')
df_10_13 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1760683456_10_13.csv')
df_10_20 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1761106034_10_20.csv')
df_10_27 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1761728246_10_27.csv')
df_11_3 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1762228692_11_3.csv')
df_11_10 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1762918577_11_10.csv')
df_11_16 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1764228350_11_16.csv')
df_11_17 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1764139740_11_17.csv')
df_11_18 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1764140060_11_18.csv')
df_11_24 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1764139385_11_24.csv')
# Out:
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_12728\123620357.py:1: DtypeWarning: Columns (23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753329431_21.csv')
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_12728\123620357.py:3: DtypeWarning: Columns (23,24,25,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_28 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753775670_28.csv')
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_12728\123620357.py:4: DtypeWarning: Columns (23,24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_8_5 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1754385922_8_5.csv')
# ---------------------------------------------------------------------------
# ...

# %%
def calculate_accuracy(df):
    date = df['day'].unique()
    df_filtered = df[df.iloc[:, 21] == "是"].iloc[:, [21, 34]]
    accuracy = (df_filtered.iloc[:, 1] == "是").sum() / (df_filtered.iloc[:, 0] == "是").sum() * 100
    return accuracy, date

dataframes = [df, df_22, df_28, df_8_5, df_8_11, df_8_18, df_8_27, df_9_2, df_9_15, df_9_29, df_10_6, df_10_13, df_10_20, df_10_27, df_11_3, df_11_10, df_11_16, df_11_17, df_11_18, df_11_24]

for i, data in enumerate(dataframes, start=1):
    ratio, date = calculate_accuracy(data)
    accuracy_history = pd.DataFrame([ratio], [date])
    
    print(f"{ratio:.2f} % Accuracy per {date}")
# Out:
# 95.99 % Accuracy per ['2025-07-21']
# 96.10 % Accuracy per ['2025-07-22']
# 97.96 % Accuracy per ['2025-07-28']
# 91.04 % Accuracy per ['2025-08-04']
# 95.46 % Accuracy per ['2025-08-11']
# 92.16 % Accuracy per ['2025-08-18']
# 99.00 % Accuracy per ['2025-08-25']
# 98.21 % Accuracy per ['2025-09-02']
# 92.38 % Accuracy per ['2025-09-15']
# 94.11 % Accuracy per ['2025-09-29']
# 98.83 % Accuracy per ['2025-10-06']
# 96.12 % Accuracy per ['2025-10-13']
# 93.55 % Accuracy per ['2025-10-20']
# 96.75 % Accuracy per ['2025-10-27']
# 96.30 % Accuracy per ['2025-11-03']
# 95.43 % Accuracy per ['2025-11-10']
# nan % Accuracy per ['2025-11-16']
# nan % Accuracy per ['2025-11-17']
# nan % Accuracy per ['2025-11-18']
# nan % Accuracy per ['2025-11-24']
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_12060\2279570701.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   accuracy = (df_filtered.iloc[:, 1] == "是").sum() / (df_filtered.iloc[:, 0] == "是").sum() * 100
# ...

# %%
def calculate_accuracy(df):
    date = df['day'].iloc[0]
    df_filtered = df[df.iloc[:, 21] == "是"].iloc[:, [21, 34]]
    denom = (df_filtered.iloc[:,0] == "是").sum()
    if denom == 0:
        return np.nan, date

    accuracy = (df_filtered.iloc[:, 1] == "是").sum() / denom * 100
    return accuracy, date

dataframes = [df, df_22, df_28, df_8_5, df_8_11, df_8_18, df_8_27, df_9_2, df_9_15, df_9_29, df_10_6, df_10_13, df_10_20, df_10_27, df_11_3, df_11_10, df_11_16,
 df_11_17, df_11_18, df_11_24]
results = []

for  data in dataframes:
    ratio, date = calculate_accuracy(data)
    results.append({
        'date': date,
        'ratio': ratio
    })

accuracy_history = pd.DataFrame(results)
accuracy_history
# Out:
#           date      ratio
# 0   2025-07-21  95.994994
# 1   2025-07-22  96.098105
# 2   2025-07-28  97.959184
# 3   2025-08-04  91.037736
# 4   2025-08-11  95.458167
# 5   2025-08-18  92.156863
# 6   2025-08-25  98.996991
# 7   2025-09-02  98.214286
# 8   2025-09-15  92.375367
# 9   2025-09-29  94.106280
# 10  2025-10-06  98.830409
# 11  2025-10-13  96.115628
# 12  2025-10-20  93.552311
# 13  2025-10-27  96.750524
# 14  2025-11-03  96.303142
# 15  2025-11-10  95.431472
# 16  2025-11-16        NaN
# 17  2025-11-17        NaN
# 18  2025-11-18        NaN
# 19  2025-11-24        NaN

# %%
accuracy_history['date'] = pd.to_datetime(accuracy_history['date'])

#visualize using matplotlib
plt.figure(figsize=(12, 6))
plt.plot(accuracy_history['date'], accuracy_history['ratio'], marker='o')
plt.title('Accuracy Over Time')
plt.xlabel('Date')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Temp

# %%
temp_1 = pd.read_csv('temp/akulaku_superset_presto_hanmm_ozy.prazuganda_1774943626.csv')
temp_2 = pd.read_csv('temp/akulaku_superset_presto_hanmm_ozy.prazuganda_1774943847.csv')
temp_3 = pd.read_csv('temp/akulaku_superset_presto_hanmm_ozy.prazuganda_1774944164.csv')
temp_4 = pd.read_csv('temp/akulaku_superset_presto_hanmm_ozy.prazuganda_1774946707.csv')
temp_5 = pd.read_csv('temp/akulaku_superset_presto_hanmm_ozy.prazuganda_1774947129.csv')
# Out:
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_12728\1789673305.py:1: DtypeWarning: Columns (32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_1 = pd.read_csv('temp/akulaku_superset_presto_hanmm_ozy.prazuganda_1774943626.csv')
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_12728\1789673305.py:2: DtypeWarning: Columns (23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_2 = pd.read_csv('temp/akulaku_superset_presto_hanmm_ozy.prazuganda_1774943847.csv')
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_12728\1789673305.py:4: DtypeWarning: Columns (23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_4 = pd.read_csv('temp/akulaku_superset_presto_hanmm_ozy.prazuganda_1774946707.csv')

# %%
df = pd.concat([temp_1, temp_2, temp_3, temp_4, temp_5], ignore_index=True)
df_sorted = df.sort_values('day')

# %%
print(f"Range tanggal data: {df_sorted['day'].min()} ~ {df_sorted['day'].max()}")
print(f"Jumlah Call ID: {df_sorted['call_id'].nunique()}")
# Out:
# Range tanggal data: 2026-03-12 ~ 2026-03-26
# Jumlah Call ID: 7092

# %%
print('Tanggal Data: ')
for i in df_sorted['day'].unique():
    print(i)
# Out:
# Tanggal Data:
# 2026-03-12
# 2026-03-13
# 2026-03-14
# 2026-03-15
# 2026-03-16
# 2026-03-18
# 2026-03-19
# 2026-03-20
# 2026-03-21
# 2026-03-22
# 2026-03-23
# 2026-03-24
# 2026-03-25
# 2026-03-26

# %%
df_new = df.groupby('call_id').size()

round(df_new.sum()/df_new.shape[0])
# Out:
# 96

# %%
df_new
# Out:
# call_id
# 0000e82673374ddeb3eca3c4f16011b5      5
# 000ce44eb7354db5bad0b305be34071c     19
# 000dcddd9ddf4ca2a452dedf83a12a26     94
# 001bd779f06546e4998e94f0d8dda317    178
# 003736f07e3241f296313f27be858b5a     31
#                                    ...
# ffdff0e3fd734746b00b7bd82e0735bc    163
# ffe41e079b8e4cc2b9459526b0247514    179
# ffe7be49d5844141a0e9f9f7d23eb433     80
# ffef89e853054c74871a4caca50336ba     31
# fff5b0005ccb46aa8116aa19d3d9b703      3
# Length: 7092, dtype: int64

# %%
workedon.to_csv('temp/hotline_data(13-26).csv', index=False)
